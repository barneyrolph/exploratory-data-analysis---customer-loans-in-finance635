# %% [markdown]
# ## Removing Highly Correlated columns

# %%
import db_utils as dbu
import pandas as pd
df = df = pd.read_csv('loan_payments_filtered.csv')

# %% [markdown]
# Let's plot a correlation matrix:

# %%
dfplot = dbu.Plotter(df)

# %%
dfplot.plot_correlation_matrix()

# %% [markdown]
# Columns to remove:
#
# - funded_amount (I didn't remove this in the end as I needed it for future analysis)
# - funded_amount_inv (I didn't remove this in the end as I needed it for future analysis)
# - instalment (I didn't remove this in the end as I needed it for future analysis)
# - out_prncp_inv
# - total_payment_inv
# - total_rec_prncp
# - collection_recovery_fee

# %%
df = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'out_prncp_inv', 'total_payment_inv', 'total_rec_prncp', 'collection_recovery_fee'])

# %%
dfplot = dbu.Plotter(df)
dfplot.plot_correlation_matrix()

# %%
df.to_csv('loan_payments_clean.csv')
