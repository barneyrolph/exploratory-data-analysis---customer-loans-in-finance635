# %% [markdown]
# ## Detecting outliers

# %% [markdown]
# Let's try to visualise any outliers then remove them from the relavent columns.

# %%
import db_utils as dbu
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv('loan_payments_more_normal.csv')

# %%
dfinf = dbu.DataFrameInfo(df)

# %%
dfinf.detect_outliers()

# %%
filtered_df = dfinf.remove_outliers(['int_rate', 'instalment', 'annual_inc', 'open_accounts', 'total_accounts', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'total_rec_int', 'last_payment_amount'])
# Out:
# Total rows removed: 14942

# %%
filtered_df.head()
# Out:
#    Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0           0  38676116   41461848         8000         8000.0
# 1           1  38656203   41440010        13200        13200.0
# 5           5  38656111   41439917         2525         2525.0
# 6           6  38656063   41439868        10000        10000.0
# 7           7  38656052   41439857        10000        10000.0
#
#    funded_amount_inv  int_rate  instalment  annual_inc    dti  ...  \
# 0             8000.0      7.49      248.82     46000.0  19.54  ...
# 1            13200.0      6.99      407.52     50000.0  24.20  ...
# 5             2525.0     11.44       83.20     32000.0   6.60  ...
# 6            10000.0     12.99      227.48     50048.0  20.67  ...
# 7            10000.0      8.19      314.25    103000.0  15.95  ...
#
#    home_ownership  verification_status  issue_date  loan_status  payment_plan  \
# 0        MORTGAGE         Not Verified  2021-01-01      Current             n
# 1            RENT         Not Verified  2021-01-01      Current             n
# 5             OWN      Source Verified  2021-01-01      Current             n
# 6            RENT      Source Verified  2021-01-01      Current             n
# 7        MORTGAGE         Not Verified  2021-01-01      Current             n
#
#             purpose  earliest_credit_line  last_payment_date  \
# 0       credit_card            1987-10-01         2022-01-01
# 1       credit_card            2001-09-01         2022-01-01
# 5  home_improvement            2011-03-01         2022-01-01
# 6       credit_card            2005-11-01         2022-01-01
# 7       credit_card            2002-02-01         2022-01-01
#
#    last_credit_pull_date  application_type
# 0             2022-01-01        INDIVIDUAL
# 1             2022-01-01        INDIVIDUAL
# 5             2022-01-01        INDIVIDUAL
# 6             2022-01-01        INDIVIDUAL
# 7             2022-01-01        INDIVIDUAL
#
# [5 rows x 54 columns]

# %%
filtered_df.to_csv('loan_payments_filtered.csv')
